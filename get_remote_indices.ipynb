# %%
import importlib
import pandas as pd
import xarray as xr
import numpy as np
import datetime as dt
from numpy import nan
from constants import *
import sys
import warnings
import math
import os
import cftime
from glob import glob
from timeit import default_timer as timer # try to measure time
from CASutils import readdata_utils as read
from CASutils import calendar_utils as cal

# %%
# define functions
def read_cmip6(filepath,datestart,dateend):
    #open netcdf dataset
    dat = xr.open_mfdataset(filepath, coords="minimal", join="override", decode_times = True, use_cftime=True)  
    #convert calendar to standard, setting missing values as NaNs
    dat = dat.convert_calendar("standard", use_cftime=True, align_on="date",missing=np.nan)
    #interpolate the dataset using cftim_range
    dateidx = xr.cftime_range(datestart,dateend,freq='D',calendar="standard") 
    dat = dat.interp(time=dateidx,method="nearest") 
    #take slice
    dat = dat.sel(time=slice(datestart, dateend))
    dat = xr.decode_cf(dat, use_cftime = True) 
    return dat

def read_slice(filepath, datestart, dateend,latmin,latmax,plev):
    """Read in a time slice from datestart to dateend and calculate the zonal mean.
    Try using datetime64 and if that doesn't work decode times manually.
    Args:
        filepath (string) = path to files e.g., "/path/to/files/*.nc"
        datestart (string) = start date for time slice
        dateend (string) = end date for time slice
    """

    try:
        dat = xr.open_mfdataset(filepath, coords="minimal", join="override",
                 decode_times=True, use_cftime=True).\
                 sel(time=slice(datestart, dateend),lat=slice(latmin,latmax))
        
        if len(plev) == 1:
            dat = dat.sel(plev=plev,method="nearest", tolerance=1) #avoid issue for models with inaccurate plevs
        else:
            dat = dat.sel(plev=slice(plev[0]+1,plev[1]-1)) #manual tolerance of 1 because method="nearest" is not implemented for slices

        try:
            datzm=dat.mean(dim="lon")
    
        except NotImplementedError: #load data first because Not implemented by dask: ! might slow down things
            dat.load()
            datzm=dat.mean(dim="lon")

        except:
            # deal with problematic coordinate names
            dat=dat.rename({"longitude":"lon", "latitude":"lat"})
            datzm=dat.mean(dim="lon")

    except:
        print("Something's wierd about the time axis, decoding manually")
        dat = xr.open_mfdataset(filepath, coords="minimal", join="override",
                   decode_times=False)
    
        try:
            datzm=dat.mean(dim="lon")
    
        except:
            # deal with problematic coordinate names
            dat=dat.rename({"longitude":"lon", "latitude":"lat"})
            datzm=dat.mean(dim="lon")
            
        datzm=xr.decode_cf(datzm, use_cftime=True)
    
        datzm=datzm.sel(time=slice(datestart, dateend),lat=slice(latmin,latmax))
        if len(plev) == 1:
            datzm = datzm.sel(plev=plev,method="nearest", tolerance=1) #avoid issue for models with inaccurate plevs
        else:
            datzm = datzm.sel(plev=slice(plev[0]+1,plev[1]-1))  #manual tolerance of 1 because method="nearest" is not implemented for slices

        datetimeindex=datzm.indexes['time'].to_datetimeindex()
        datzm['time'] = datetimeindex

    return datzm

def read_field(filepath, datestart, dateend,latmin,latmax,lonmin,lonmax,plev,norm=False):
    """Read in a time slice from datestart to dateend and calculate the zonal mean.
    Try using datetime64 and if that doesn't work decode times manually.
    Args:
        filepath (string) = path to files e.g., "/path/to/files/*.nc"
        datestart (string) = start date for time slice
        dateend (string) = end date for time slice
    """

    try:
        dat = xr.open_mfdataset(filepath, coords="minimal", join="override",
                 decode_times=True, use_cftime=True)
        if norm:
            dat = norm_lon(dat)
        
        dat = dat.sel(time=slice(datestart, dateend),lat=slice(latmin,latmax),lon=slice(lonmin,lonmax))
        
        if len(plev) == 1:
            dat = dat.sel(plev=plev,method="nearest", tolerance=1) #avoid issue for models with inaccurate plevs
        else:
            dat = dat.sel(plev=slice(plev[0]+1,plev[1]-1)) #manual tolerance of 1 because method="nearest" is not implemented for slices

    except:
        print("Something's wierd about the time axis, decoding manually")
        dat = xr.open_mfdataset(filepath, coords="minimal", join="override",
                   decode_times=False)
        if norm: 
            dat = norm_lon(dat)
        dat=xr.decode_cf(dat, use_cftime=True)
    
        dat=dat.sel(time=slice(datestart, dateend),lat=slice(latmin,latmax),lon=slice(lonmin,lonmax))
        if len(plev) == 1:
            dat = dat.sel(plev=plev,method="nearest", tolerance=1) #avoid issue for models with inaccurate plevs
        else:
            dat = dat.sel(plev=slice(plev[0]+1,plev[1]-1))  #manual tolerance of 1 because method="nearest" is not implemented for slices

        datetimeindex=dat.indexes['time'].to_datetimeindex()
        dat['time'] = datetimeindex

    return dat



def get_lat_lon_res(ds):
    '''Function to obtain the average lat and lon gridspacing from a dataset of a non regular model grid. '''
    lat = ds.coords['lat']
    lon = ds.coords['lon']
    difflat = lat - lat.shift(lat=1)
    latres = difflat.mean().to_numpy()
    difflon = lon - lon.shift(lon=1)
    lonres = difflon.mean().to_numpy()
    return latres, lonres

def def_domain(ncdf,min_lat,max_lat,min_lon,max_lon):
    LatIndexer, LonIndexer = 'lat', 'lon'
    ncdf = ncdf.loc[{LatIndexer: slice(min_lat, max_lat),
                      LonIndexer: slice(min_lon, max_lon)}]
    return ncdf

def norm_lon(ncdf):
    ncdf.coords['lon'] = (ncdf.coords['lon'] + 180) % 360 - 180
    return ncdf.sortby(ncdf.lon)

def get_ONDJFM_day(ncdf, months=[1,2,3,10,11,12],timedim="day"):
    return ncdf.isel({timedim:ncdf[timedim].dt.month.isin(months)})

def area_weighted_avg(ds):
    '''Weighted average over the latitudinal coordinate'''
    lat = ds.lat.values
    AreaWeight = np.cos(lat*np.pi/180)
    #AreaWeight = AreaWeight/np.average(AreaWeight) #Normalize weight
    ds_avg = np.average(ds,axis=1,weights = AreaWeight)
    return ds_avg

# %%
#os.chdir('/home/lseverino/MT/scripts')
importlib.reload(read)
importlib.reload(cal)
warnings.filterwarnings('ignore')

# %%
## constants
#paths
histpath="/net/atmos/data/cmip6/historical/"
ssp119path="/net/atmos/data/cmip6/ssp119/"
ssp126path="/net/atmos/data/cmip6/ssp126/"
ssp245path="/net/atmos/data/cmip6/ssp245/"
ssp370path="/net/atmos/data/cmip6/ssp370/"
ssp585path="/net/atmos/data/cmip6/ssp585/"

scenlist = ["historical","ssp126","ssp245","ssp370","ssp585"]
pathlist = [histpath,ssp126path,ssp245path,ssp370path,ssp585path]
pathdic = {"historical":histpath,"ssp126":ssp126path,"ssp245":ssp245path,"ssp370":ssp370path,"ssp585":ssp585path}
var="sfcWindmax"
pathout="../cmip6/"+var+'/'

cmip6models=pd.read_csv('../cmip6csvinfo/cmip6csvinfo_timeseries_ssp585_luca_daily.csv')

# %% [raw]
# # get directories and member names
# nmems_hist = dict()
# #nmems_ssp119 = dict()
# nmems_ssp126 = dict()
# nmems_ssp245 = dict()
# nmems_ssp370 = dict()
# nmems_ssp585 = dict()
# models_df = pd.DataFrame(columns=scenlist)
# for ind,path in enumerate(pathlist):
#     for subdir in os.scandir(path+var):
#         models_df.loc[subdir.name,scenlist[ind]] = len(os.listdir(subdir))
#
# models_df.loc["total",:] = models_df.count(axis=0)

# %% [markdown]
# #select all models with minimum 3 members for the 5 scenarios
# mods_3mem_allscen = models_df.where(models_df>=3).dropna(how='any').iloc[:-1,:]
# mods_1mem_allscen = models_df.where(models_df>=1).dropna(how='any').iloc[:-1,:]

# %%
# populate dict with model names and member names
# force to get the same members as for sfcWindmax
varSWM = 'day/sfcWindmax'
dicscen = dict()
for ind,scen in enumerate(scenlist):
    path = pathlist[ind]
    dicscen[scen] = dict()
    for subdir in os.scandir(path+varSWM):
        #models_rcp85[subdir.name]=[]
        dicscen[scen][subdir.name] = [len(os.listdir(subdir))]
        dicscen[scen][subdir.name].append(os.listdir(subdir))
nmems_hist = dicscen['historical']
nmems_ssp585 = dicscen['ssp585']

# %% [raw]
# # turn dicts into pd DataFrames because more convenient
# nmems_hist_df = pd.DataFrame(nmems_hist, index=["hist","memnames"])
# nmems_ssp585_df = pd.DataFrame(nmems_ssp585, index=["ssp585","memnames"])

# %% [raw]
# # get common models that are both in historical and rcp85
# nmems_hist_com = nmems_hist_df.reindex(nmems_ssp585_df.columns,axis=1).dropna(axis=1)
# nmems_ssp585_com = nmems_ssp585_df.reindex(nmems_hist_df.columns,axis=1).dropna(axis=1)

# %%
#consider ONJDFM: start in D, finishes in M, adjust to have same number of days in both periods
ybegp = 1980 ; monbegp = 10 ; yendp = 2010 ; monendp = 3 ; daybegp = 1 ; dayendp = 30# dates for Past period, only takes 30th 
#ybegf = 2070 ; monbegf = 1 ; yendf = 2099 ; monendf = 12 ; daybegf = 1 ; dayendf = 31# dates for Future period
ybegf = 2070 ; monbegf = 10 ; yendf = 2100 ; monendf = 3 ; daybegf = 1 ; dayendf = 30# otherwise dont have the same length

# total number of months (used for checking)
nmonthsp = (yendp-ybegp-1)*12 + (12-monbegp+1) + monendp
nmonthsf = (yendf-ybegf-1)*12 + (12-monbegf+1) + monendf

# set up date names
dateformat ='%Y-%m-%d'

datebegp=str(ybegp)+"-"+str(monbegp).zfill(2)+"-"+str(daybegp).zfill(2)
dateendp=str(yendp)+"-"+str(monendp).zfill(2)+"-"+str(dayendp).zfill(2)
datebegf=str(ybegf)+"-"+str(monbegf).zfill(2)+"-"+str(daybegf).zfill(2)
dateendf=str(yendf)+"-"+str(monendf).zfill(2)+"-"+str(dayendf).zfill(2)

#set up daterange indexes
#daysidp = pd.date_range(datebegp,dateendp,freq='D')
#daysidf = pd.date_range(datebegf,dateendf,freq='D')

daysidp = xr.cftime_range(datebegp,dateendp,freq='D',calendar='standard')
daysidf = xr.cftime_range(datebegf,dateendf,freq='D',calendar='standard')

#nb of days
ndaysp = len(daysidp)
ndaysf = len(daysidf)

dayrangep = np.arange(1,ndaysp+1,1)
dayrangef = np.arange(1,ndaysf+1,1)

monrangep = np.arange(1,nmonthsp+1,1)
monrangef = np.arange(1,nmonthsf+1,1)

latout=np.linspace(-90,90,73)
lonout=np.linspace(0,357.5,144)
#lonout=np.linspace(0,360,144) # try to remove issues at border

# plevuse=[100000,92500,85000,70000,60000,50000,40000,30000,25000,20000,15000,10000,
#        7000,5000,3000,2000,1000]
# plevuse=[1000]

# %%
##select variables
#models

modlist = modlist_ssp585 + modlist_allscen
#modlist = modlist[:2]
modset = "modlist_allmods"
models = pd.Series(modlist)
nmods = len(modlist)
#scenarios
selscen = ["historical",'ssp585']
nscens = len(selscen)

#indices from O2020
#[Tres,var,latmin, latmax,lonmin,lonmax,pmax,pmin]
#ind_dict = {"sfcT":["Amon","tas",np.nan,np.nan,np.nan,np.nan,np.nan],"pol": ["Amon","ta",60,90,np.nan,np.nan,100000,70000],
#            "trop":["Amon","ta",-20,20,np.nan,np.nan,40000,15000],"strat":["Amon","ua",70,90,np.nan,np.nan,25000,3000],
#           "Nino4":["Amon","tas",-5,5,160,210,np.nan,np.nan],"Nino3":["Amon","tas",-5,5,210,270,np.nan],
#            "NAWH":["Amon","tas",35,60,320,350,np.nan,np.nan]}

#indices from ZS2017
#ind_dict = {"sfcT":["Amon","tas",np.nan,np.nan,np.nan,np.nan,np.nan],"pol": ["Amon","ta",60,90,np.nan,np.nan,85000],
#            "trop":["Amon","ta",-30,30,np.nan,np.nan,25000],"strat":["Amon","ua",70,80,np.nan,np.nan,2000]}

#indices from Cu2021
# normalize lon + take winter avg anomalies!!
ind_dict = {"NAO-neg1":["Amon","zg",50,82,-91,30,50000],"NAO-pos1":["Amon","zg",31,49,-63,-5,50000],
            "EA-neg1":["Amon","zg",59,71,63,99,50000],"EA-neg2":["Amon","zg",45,61,-49,-2,50000],
            "EA-pos1":["Amon","zg",9,34,-70,25,50000],"EAWR-neg1":["Amon","zg",37,66,33,68,50000],
            "EAWR-pos1":["Amon","zg",34,50,100,140,50000],"EAWR-pos2":["Amon","zg",44,60,-10,13,50000],
            "SCA-neg1":["Amon","zg",37,56,80,118,50000],"SCA-neg2":["Amon","zg",33,41,-21,9,50000],
            "SCA-pos1":["Amon","zg",63,75,-35,53,50000],
           }

##custom indices
#ind_dict = {"Sbox":["Amon","ta",15,35,280,330,95000,85000],"Nbox":["Amon","ta",40,60,320,350,95000,85000],
#           "TCWV":["Amon","prw",40,60,315,345,np.nan,np.nan]}

ind_list = list(ind_dict.keys())
#ind_list = ind_list[:2]

normalize_lon = True #True when indices given in normalized lon
win_ano = True #take anomalies wrt winter averaged

#define types of indices
sfcfields = ["sfcT","Nino4","Nino3","NAWH","TCWV"]
lonmeanfields = ["pol","trop","strat"]
pslices = ["pol","trop","strat","TCWV","Sbox","Nbox","NAO-neg1","EA-neg1","EA-pos1","EAWR-pos1",
           "SCA-neg1","SCA-pos1","NAO-pos1","EA-neg2","EAWR-neg1","EAWR-pos2","SCA-neg2"]


#select maximum of members to use 
nmems_max = 3
mem_idx = range(nmems_max)
#initiate df to store results
iterrows = [modlist,mem_idx]
row_idx= pd.MultiIndex.from_product(iterrows,names=["model","imem"])
itercols = [ind_list,selscen]

col_idx= pd.MultiIndex.from_product(itercols,names=["indice","scen"])

ind_df = pd.DataFrame(index=row_idx,columns=col_idx)
savename="_".join(["WAN","weather","indices","CU21","sp_avg",modset]+selscen)+".csv"


#initiate ds to save time series
nmonths = 180 #30*6 months of data
monrange = np.arange(1,nmonths+1,1)
ds_dict = {}
for indice in ind_list:
    ds_dict[indice]=xr.DataArray(np.nan*np.ones([nmods ,nmems_max,nscens,nmonths]), coords=[modlist, mem_idx, selscen ,monrange], dims=['model','member','scen','month'],name=indice) 
    
ind_ds = xr.Dataset(ds_dict)

#get member names
memname_df = pd.read_csv('/home/lseverino/MT/metadata/memnames_ssp585_hist_SWM.csv',header=[0,1],index_col=0)

# %%
#remote indices: taking the average

nmods = len(models)
memout=np.arange(0,nmem_max)
modout=np.arange(0,nmods)

for index, modname in models.iteritems():
    
    members = memname_df.loc[modname,scen]
    nmems = nmem_max - members.isna().sum()
    
    #iterate over the scenarios
    for scen in selscen:    
            scenpath = pathdic[scen]
            #select date
            if scen == 'historical':
                datebeg = datebegp
                dateend = dateendp
                nmonths = nmonthsp
            else: 
                datebeg = datebegf
                dateend = dateendf
                nmonths = nmonthsf
            
            #iterate over the members
            for imem in range(nmems):
                #select member (same as the one used for damage computation)
                memname = memname_df.loc[modname,(scen,str(imem))]
                
                #iterate over the indices
                for indice in ind_list:
                    #select var, lat and plev
                    infos = ind_dict[indice]
                    dirv = infos[0]
                    var = infos[1]
                    latmin = infos[2]
                    latmax = infos[3]
                    lonmin = infos[4]
                    lonmax = infos[5]
                    plev = infos[6:]
                    
                    
                    #paths
                    scendir = glob(scenpath+"/"+dirv+"/"+var+"/"+modname+"/"+memname+"/*/")
                    scendir = scendir[0]
                    print("Processing "+indice+" "+scen+" for "+modname+" "+memname+"...")
                    
                    if indice in sfcfields:
                        field = read.read_sfc(scendir+"*.nc", datebeg,dateend)
                    
                    elif indice in lonmeanfields:
                        try:
                            field = read_slice(scendir+"*.nc", datebeg,dateend,latmin,latmax,plev)
                
                        except ValueError:
                            #assume first file contains what we need
                            fpath = glob(scenpath+"/"+dirv+"/"+var+"/"+modname+"/"+memname+"/*/*.nc")[0] 
                            print("Look into: "+fpath)
                            field = read_slice(fpath, datebeg,dateend,latmin,latmax,plev)
                    else:
                        try:
                            field = read_field(scendir+"*.nc", datebeg,dateend,latmin,latmax,lonmin,lonmax,plev,norm=normalize_lon)
                
                        except ValueError:
                            #assume first file contains what we need
                            fpath = glob(scenpath+"/"+dirv+"/"+var+"/"+modname+"/"+memname+"/*/*.nc")[0] 
                            print("Look into: "+fpath)
                            field = read_field(fpath, datebeg,dateend,latmin,latmax,lonmin,lonmax,plev,norm=normalize_lon)
                        
                    
                    field = field[var]
            
                    #check that everything good with time axis
                    
                    if (field.time.size !=  nmonths):
                        print("something's wrong, nmonths="+str(nmonths)+" but field has size "+str(field.time.size))
                    
                
                    ## do appropriate means and selection
                    
                    if indice in ["Nino4","Nino3","NAWH","TCWV"]:
                        field = field.sel(lon=slice(lonmin,lonmax))
                          
                    if indice in pslices:
                        field = field.mean(dim="plev")
                    
                    #select ONDJFM only if not global warming
                    if indice!="sfcT":
                        field = get_ONDJFM_day(field,timedim="time")
                        
                    #lon average if not already done
                    if indice not in lonmeanfields:
                        field = field.mean(dim=("lon"))   
                        
                    
                    if win_ano:
                        field = field.groupby('time.month') - field.groupby('time.month').mean()
                    
                    #do approximate area weighted average
                    field_avg = area_weighted_avg(field)
                    
                    ind_ds[indice].loc[dict(model=modname,member=imem,scen=scen,month=monrange)] = field_avg
                    #average over time dimension and write into dataframe
                    ind_df.loc[(modname,imem),(indice,scen)] = field_avg.mean()
                    
                    del field
                        
ind_df = ind_df.astype(np.float64)
ind_df.to_csv("/home/lseverino/MT/circulation/"+savename)
# Out:
# Processing NAO-neg1 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing NAO-pos1 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing EA-neg1 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing EA-neg2 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing EA-pos1 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing EAWR-neg1 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing EAWR-pos1 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing EAWR-pos2 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing SCA-neg1 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing SCA-neg2 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing SCA-pos1 historical for AWI-CM-1-1-MR r1i1p1f1...
# Processing NAO-neg1 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing NAO-pos1 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing EA-neg1 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing EA-neg2 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing EA-pos1 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing EAWR-neg1 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing EAWR-pos1 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing EAWR-pos2 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing SCA-neg1 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing SCA-neg2 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing SCA-pos1 ssp585 for AWI-CM-1-1-MR r1i1p1f1...
# Processing NAO-neg1 historical for BCC-CSM2-MR r1i1p1f1...
# Processing NAO-pos1 historical for BCC-CSM2-MR r1i1p1f1...
# Processing EA-neg1 historical for BCC-CSM2-MR r1i1p1f1...
# Processing EA-neg2 historical for BCC-CSM2-MR r1i1p1f1...
# Processing EA-pos1 historical for BCC-CSM2-MR r1i1p1f1...
# Processing EAWR-neg1 historical for BCC-CSM2-MR r1i1p1f1...
# Processing EAWR-pos1 historical for BCC-CSM2-MR r1i1p1f1...
# Processing EAWR-pos2 historical for BCC-CSM2-MR r1i1p1f1...
# Processing SCA-neg1 historical for BCC-CSM2-MR r1i1p1f1...
# Processing SCA-neg2 historical for BCC-CSM2-MR r1i1p1f1...
# Processing SCA-pos1 historical for BCC-CSM2-MR r1i1p1f1...
# Processing NAO-neg1 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing NAO-pos1 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing EA-neg1 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing EA-neg2 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing EA-pos1 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing EAWR-neg1 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing EAWR-pos1 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing EAWR-pos2 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing SCA-neg1 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing SCA-neg2 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing SCA-pos1 ssp585 for BCC-CSM2-MR r1i1p1f1...
# Processing NAO-neg1 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing NAO-pos1 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing EA-neg1 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing EA-neg2 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing EA-pos1 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing EAWR-neg1 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing EAWR-pos1 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing EAWR-pos2 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing SCA-neg1 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing SCA-neg2 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing SCA-pos1 historical for CNRM-CM6-1-HR r1i1p1f2...
# Processing NAO-neg1 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing NAO-pos1 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing EA-neg1 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing EA-neg2 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing EA-pos1 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing EAWR-neg1 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing EAWR-pos1 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing EAWR-pos2 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing SCA-neg1 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing SCA-neg2 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing SCA-pos1 ssp585 for CNRM-CM6-1-HR r1i1p1f2...
# Processing NAO-neg1 historical for EC-Earth3-CC r1i1p1f1...
# Processing NAO-pos1 historical for EC-Earth3-CC r1i1p1f1...
# Processing EA-neg1 historical for EC-Earth3-CC r1i1p1f1...
# Processing EA-neg2 historical for EC-Earth3-CC r1i1p1f1...
# Processing EA-pos1 historical for EC-Earth3-CC r1i1p1f1...
# Processing EAWR-neg1 historical for EC-Earth3-CC r1i1p1f1...
# Processing EAWR-pos1 historical for EC-Earth3-CC r1i1p1f1...
# Processing EAWR-pos2 historical for EC-Earth3-CC r1i1p1f1...
# Processing SCA-neg1 historical for EC-Earth3-CC r1i1p1f1...
# Processing SCA-neg2 historical for EC-Earth3-CC r1i1p1f1...
# Processing SCA-pos1 historical for EC-Earth3-CC r1i1p1f1...
# Processing NAO-neg1 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing NAO-pos1 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing EA-neg1 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing EA-neg2 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing EA-pos1 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing EAWR-neg1 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing EAWR-pos1 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing EAWR-pos2 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing SCA-neg1 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing SCA-neg2 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing SCA-pos1 ssp585 for EC-Earth3-CC r1i1p1f1...
# Processing NAO-neg1 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing NAO-pos1 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing EA-neg1 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing EA-neg2 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing EA-pos1 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing EAWR-neg1 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing EAWR-pos1 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing EAWR-pos2 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing SCA-neg1 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing SCA-neg2 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing SCA-pos1 historical for HadGEM3-GC31-LL r1i1p1f3...
# Processing NAO-neg1 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing NAO-pos1 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing EA-neg1 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing EA-neg2 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing EA-pos1 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing EAWR-neg1 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing EAWR-pos1 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing EAWR-pos2 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing SCA-neg1 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing SCA-neg2 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing SCA-pos1 historical for HadGEM3-GC31-LL r2i1p1f3...
# Processing NAO-neg1 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing NAO-pos1 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing EA-neg1 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing EA-neg2 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing EA-pos1 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing EAWR-neg1 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing EAWR-pos1 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing EAWR-pos2 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing SCA-neg1 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing SCA-neg2 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing SCA-pos1 historical for HadGEM3-GC31-LL r3i1p1f3...
# Processing NAO-neg1 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing NAO-pos1 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing EA-neg1 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing EA-neg2 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing EA-pos1 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing EAWR-neg1 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing EAWR-pos1 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing EAWR-pos2 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing SCA-neg1 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing SCA-neg2 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing SCA-pos1 ssp585 for HadGEM3-GC31-LL r1i1p1f3...
# Processing NAO-neg1 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing NAO-pos1 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing EA-neg1 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing EA-neg2 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing EA-pos1 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing EAWR-neg1 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing EAWR-pos1 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing EAWR-pos2 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing SCA-neg1 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing SCA-neg2 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing SCA-pos1 ssp585 for HadGEM3-GC31-LL r3i1p1f3...
# Processing NAO-neg1 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing NAO-pos1 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing EA-neg1 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing EA-neg2 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing EA-pos1 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing EAWR-neg1 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing EAWR-pos1 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing EAWR-pos2 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing SCA-neg1 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing SCA-neg2 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing SCA-pos1 ssp585 for HadGEM3-GC31-LL r2i1p1f3...
# Processing NAO-neg1 historical for GISS-E2-1-G r1i1p1f1...
# Processing NAO-pos1 historical for GISS-E2-1-G r1i1p1f1...
# Processing EA-neg1 historical for GISS-E2-1-G r1i1p1f1...
# Processing EA-neg2 historical for GISS-E2-1-G r1i1p1f1...
# Processing EA-pos1 historical for GISS-E2-1-G r1i1p1f1...
# Processing EAWR-neg1 historical for GISS-E2-1-G r1i1p1f1...
# Processing EAWR-pos1 historical for GISS-E2-1-G r1i1p1f1...
# Processing EAWR-pos2 historical for GISS-E2-1-G r1i1p1f1...
# Processing SCA-neg1 historical for GISS-E2-1-G r1i1p1f1...
# Processing SCA-neg2 historical for GISS-E2-1-G r1i1p1f1...
# Processing SCA-pos1 historical for GISS-E2-1-G r1i1p1f1...
# Processing NAO-neg1 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing NAO-pos1 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing EA-neg1 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing EA-neg2 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing EA-pos1 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing EAWR-neg1 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing EAWR-pos1 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing EAWR-pos2 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing SCA-neg1 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing SCA-neg2 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing SCA-pos1 ssp585 for GISS-E2-1-G r1i1p1f2...
# Processing NAO-neg1 historical for GFDL-CM4 r1i1p1f1...
# Processing NAO-pos1 historical for GFDL-CM4 r1i1p1f1...
# Processing EA-neg1 historical for GFDL-CM4 r1i1p1f1...
# Processing EA-neg2 historical for GFDL-CM4 r1i1p1f1...
# Processing EA-pos1 historical for GFDL-CM4 r1i1p1f1...
# Processing EAWR-neg1 historical for GFDL-CM4 r1i1p1f1...
# Processing EAWR-pos1 historical for GFDL-CM4 r1i1p1f1...
# Processing EAWR-pos2 historical for GFDL-CM4 r1i1p1f1...
# Processing SCA-neg1 historical for GFDL-CM4 r1i1p1f1...
# Processing SCA-neg2 historical for GFDL-CM4 r1i1p1f1...
# Processing SCA-pos1 historical for GFDL-CM4 r1i1p1f1...
# Processing NAO-neg1 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing NAO-pos1 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing EA-neg1 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing EA-neg2 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing EA-pos1 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing EAWR-neg1 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing EAWR-pos1 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing EAWR-pos2 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing SCA-neg1 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing SCA-neg2 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing SCA-pos1 ssp585 for GFDL-CM4 r1i1p1f1...
# Processing NAO-neg1 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing NAO-pos1 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing EA-neg1 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing EA-neg2 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing EA-pos1 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing EAWR-neg1 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing EAWR-pos1 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing EAWR-pos2 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing SCA-neg1 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing SCA-neg2 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing SCA-pos1 historical for CMCC-CM2-SR5 r1i1p1f1...
# Processing NAO-neg1 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing NAO-pos1 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing EA-neg1 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing EA-neg2 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing EA-pos1 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing EAWR-neg1 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing EAWR-pos1 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing EAWR-pos2 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing SCA-neg1 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing SCA-neg2 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing SCA-pos1 ssp585 for CMCC-CM2-SR5 r1i1p1f1...
# Processing NAO-neg1 historical for CMCC-ESM2 r1i1p1f1...
# Processing NAO-pos1 historical for CMCC-ESM2 r1i1p1f1...
# Processing EA-neg1 historical for CMCC-ESM2 r1i1p1f1...
# Processing EA-neg2 historical for CMCC-ESM2 r1i1p1f1...
# Processing EA-pos1 historical for CMCC-ESM2 r1i1p1f1...
# Processing EAWR-neg1 historical for CMCC-ESM2 r1i1p1f1...
# Processing EAWR-pos1 historical for CMCC-ESM2 r1i1p1f1...
# Processing EAWR-pos2 historical for CMCC-ESM2 r1i1p1f1...
# Processing SCA-neg1 historical for CMCC-ESM2 r1i1p1f1...
# Processing SCA-neg2 historical for CMCC-ESM2 r1i1p1f1...
# Processing SCA-pos1 historical for CMCC-ESM2 r1i1p1f1...
# Processing NAO-neg1 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing NAO-pos1 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing EA-neg1 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing EA-neg2 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing EA-pos1 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing EAWR-neg1 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing EAWR-pos1 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing EAWR-pos2 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing SCA-neg1 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing SCA-neg2 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing SCA-pos1 ssp585 for CMCC-ESM2 r1i1p1f1...
# Processing NAO-neg1 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing NAO-pos1 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing EA-neg1 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing EA-neg2 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing EA-pos1 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing EAWR-neg1 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing EAWR-pos1 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing EAWR-pos2 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing SCA-neg1 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing SCA-neg2 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing SCA-pos1 historical for HadGEM3-GC31-MM r1i1p1f3...
# Processing NAO-neg1 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing NAO-pos1 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing EA-neg1 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing EA-neg2 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing EA-pos1 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing EAWR-neg1 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing EAWR-pos1 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing EAWR-pos2 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing SCA-neg1 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing SCA-neg2 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing SCA-pos1 historical for HadGEM3-GC31-MM r2i1p1f3...
# Processing NAO-neg1 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing NAO-pos1 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing EA-neg1 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing EA-neg2 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing EA-pos1 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing EAWR-neg1 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing EAWR-pos1 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing EAWR-pos2 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing SCA-neg1 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing SCA-neg2 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing SCA-pos1 historical for HadGEM3-GC31-MM r4i1p1f3...
# Processing NAO-neg1 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing NAO-pos1 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing EA-neg1 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing EA-neg2 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing EA-pos1 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing EAWR-neg1 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing EAWR-pos1 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing EAWR-pos2 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing SCA-neg1 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing SCA-neg2 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing SCA-pos1 ssp585 for HadGEM3-GC31-MM r1i1p1f3...
# Processing NAO-neg1 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing NAO-pos1 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing EA-neg1 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing EA-neg2 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing EA-pos1 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing EAWR-neg1 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing EAWR-pos1 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing EAWR-pos2 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing SCA-neg1 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing SCA-neg2 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing SCA-pos1 ssp585 for HadGEM3-GC31-MM r3i1p1f3...
# Processing NAO-neg1 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing NAO-pos1 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing EA-neg1 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing EA-neg2 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing EA-pos1 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing EAWR-neg1 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing EAWR-pos1 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing EAWR-pos2 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing SCA-neg1 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing SCA-neg2 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing SCA-pos1 ssp585 for HadGEM3-GC31-MM r2i1p1f3...
# Processing NAO-neg1 historical for NESM3 r1i1p1f1...
# Processing NAO-pos1 historical for NESM3 r1i1p1f1...
# Processing EA-neg1 historical for NESM3 r1i1p1f1...
# Processing EA-neg2 historical for NESM3 r1i1p1f1...
# Processing EA-pos1 historical for NESM3 r1i1p1f1...
# Processing EAWR-neg1 historical for NESM3 r1i1p1f1...
# Processing EAWR-pos1 historical for NESM3 r1i1p1f1...
# Processing EAWR-pos2 historical for NESM3 r1i1p1f1...
# Processing SCA-neg1 historical for NESM3 r1i1p1f1...
# Processing SCA-neg2 historical for NESM3 r1i1p1f1...
# Processing SCA-pos1 historical for NESM3 r1i1p1f1...
# Processing NAO-neg1 historical for NESM3 r2i1p1f1...
# Processing NAO-pos1 historical for NESM3 r2i1p1f1...
# Processing EA-neg1 historical for NESM3 r2i1p1f1...
# Processing EA-neg2 historical for NESM3 r2i1p1f1...
# Processing EA-pos1 historical for NESM3 r2i1p1f1...
# Processing EAWR-neg1 historical for NESM3 r2i1p1f1...
# Processing EAWR-pos1 historical for NESM3 r2i1p1f1...
# Processing EAWR-pos2 historical for NESM3 r2i1p1f1...
# Processing SCA-neg1 historical for NESM3 r2i1p1f1...
# Processing SCA-neg2 historical for NESM3 r2i1p1f1...
# Processing SCA-pos1 historical for NESM3 r2i1p1f1...
# Processing NAO-neg1 ssp585 for NESM3 r2i1p1f1...
# Processing NAO-pos1 ssp585 for NESM3 r2i1p1f1...
# Processing EA-neg1 ssp585 for NESM3 r2i1p1f1...
# Processing EA-neg2 ssp585 for NESM3 r2i1p1f1...
# Processing EA-pos1 ssp585 for NESM3 r2i1p1f1...
# Processing EAWR-neg1 ssp585 for NESM3 r2i1p1f1...
# Processing EAWR-pos1 ssp585 for NESM3 r2i1p1f1...
# Processing EAWR-pos2 ssp585 for NESM3 r2i1p1f1...
# Processing SCA-neg1 ssp585 for NESM3 r2i1p1f1...
# Processing SCA-neg2 ssp585 for NESM3 r2i1p1f1...
# Processing SCA-pos1 ssp585 for NESM3 r2i1p1f1...
# Processing NAO-neg1 ssp585 for NESM3 r1i1p1f1...
# Processing NAO-pos1 ssp585 for NESM3 r1i1p1f1...
# Processing EA-neg1 ssp585 for NESM3 r1i1p1f1...
# Processing EA-neg2 ssp585 for NESM3 r1i1p1f1...
# Processing EA-pos1 ssp585 for NESM3 r1i1p1f1...
# Processing EAWR-neg1 ssp585 for NESM3 r1i1p1f1...
# Processing EAWR-pos1 ssp585 for NESM3 r1i1p1f1...
# Processing EAWR-pos2 ssp585 for NESM3 r1i1p1f1...
# Processing SCA-neg1 ssp585 for NESM3 r1i1p1f1...
# Processing SCA-neg2 ssp585 for NESM3 r1i1p1f1...
# Processing SCA-pos1 ssp585 for NESM3 r1i1p1f1...
# Processing NAO-neg1 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing NAO-pos1 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing EA-neg1 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing EA-neg2 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing EA-pos1 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing EAWR-neg1 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing EAWR-pos1 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing EAWR-pos2 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing SCA-neg1 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing SCA-neg2 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing SCA-pos1 historical for MPI-ESM1-2-HR r10i1p1f1...
# Processing NAO-neg1 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing NAO-pos1 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing EA-neg1 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing EA-neg2 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing EA-pos1 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing EAWR-neg1 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing EAWR-pos1 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing EAWR-pos2 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing SCA-neg1 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing SCA-neg2 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing SCA-pos1 historical for MPI-ESM1-2-HR r4i1p1f1...
# Processing NAO-neg1 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing NAO-pos1 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing EA-neg1 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing EA-neg2 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing EA-pos1 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing EAWR-neg1 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing EAWR-pos1 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing EAWR-pos2 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing SCA-neg1 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing SCA-neg2 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing SCA-pos1 ssp585 for MPI-ESM1-2-HR r1i1p1f1...
# Processing NAO-neg1 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing NAO-pos1 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing EA-neg1 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing EA-neg2 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing EA-pos1 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing EAWR-neg1 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing EAWR-pos1 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing EAWR-pos2 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing SCA-neg1 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing SCA-neg2 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing SCA-pos1 ssp585 for MPI-ESM1-2-HR r2i1p1f1...
# Processing NAO-neg1 historical for INM-CM4-8 r1i1p1f1...
# Processing NAO-pos1 historical for INM-CM4-8 r1i1p1f1...
# Processing EA-neg1 historical for INM-CM4-8 r1i1p1f1...
# Processing EA-neg2 historical for INM-CM4-8 r1i1p1f1...
# Processing EA-pos1 historical for INM-CM4-8 r1i1p1f1...
# Processing EAWR-neg1 historical for INM-CM4-8 r1i1p1f1...
# Processing EAWR-pos1 historical for INM-CM4-8 r1i1p1f1...
# Processing EAWR-pos2 historical for INM-CM4-8 r1i1p1f1...
# Processing SCA-neg1 historical for INM-CM4-8 r1i1p1f1...
# Processing SCA-neg2 historical for INM-CM4-8 r1i1p1f1...
# Processing SCA-pos1 historical for INM-CM4-8 r1i1p1f1...
# Processing NAO-neg1 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing NAO-pos1 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing EA-neg1 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing EA-neg2 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing EA-pos1 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing EAWR-neg1 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing EAWR-pos1 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing EAWR-pos2 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing SCA-neg1 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing SCA-neg2 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing SCA-pos1 ssp585 for INM-CM4-8 r1i1p1f1...
# Processing NAO-neg1 historical for INM-CM5-0 r5i1p1f1...
# Processing NAO-pos1 historical for INM-CM5-0 r5i1p1f1...
# Processing EA-neg1 historical for INM-CM5-0 r5i1p1f1...
# Processing EA-neg2 historical for INM-CM5-0 r5i1p1f1...
# Processing EA-pos1 historical for INM-CM5-0 r5i1p1f1...
# Processing EAWR-neg1 historical for INM-CM5-0 r5i1p1f1...
# Processing EAWR-pos1 historical for INM-CM5-0 r5i1p1f1...
# Processing EAWR-pos2 historical for INM-CM5-0 r5i1p1f1...
# Processing SCA-neg1 historical for INM-CM5-0 r5i1p1f1...
# Processing SCA-neg2 historical for INM-CM5-0 r5i1p1f1...
# Processing SCA-pos1 historical for INM-CM5-0 r5i1p1f1...
# Processing NAO-neg1 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing NAO-pos1 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing EA-neg1 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing EA-neg2 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing EA-pos1 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing EAWR-neg1 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing EAWR-pos1 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing EAWR-pos2 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing SCA-neg1 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing SCA-neg2 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing SCA-pos1 ssp585 for INM-CM5-0 r1i1p1f1...
# Processing NAO-neg1 historical for ACCESS-CM2 r4i1p1f1...
# Processing NAO-pos1 historical for ACCESS-CM2 r4i1p1f1...
# Processing EA-neg1 historical for ACCESS-CM2 r4i1p1f1...
# Processing EA-neg2 historical for ACCESS-CM2 r4i1p1f1...
# Processing EA-pos1 historical for ACCESS-CM2 r4i1p1f1...
# Processing EAWR-neg1 historical for ACCESS-CM2 r4i1p1f1...
# Processing EAWR-pos1 historical for ACCESS-CM2 r4i1p1f1...
# Processing EAWR-pos2 historical for ACCESS-CM2 r4i1p1f1...
# Processing SCA-neg1 historical for ACCESS-CM2 r4i1p1f1...
# Processing SCA-neg2 historical for ACCESS-CM2 r4i1p1f1...
# Processing SCA-pos1 historical for ACCESS-CM2 r4i1p1f1...
# Processing NAO-neg1 historical for ACCESS-CM2 r5i1p1f1...
# Processing NAO-pos1 historical for ACCESS-CM2 r5i1p1f1...
# Processing EA-neg1 historical for ACCESS-CM2 r5i1p1f1...
# Processing EA-neg2 historical for ACCESS-CM2 r5i1p1f1...
# Processing EA-pos1 historical for ACCESS-CM2 r5i1p1f1...
# Processing EAWR-neg1 historical for ACCESS-CM2 r5i1p1f1...
# Processing EAWR-pos1 historical for ACCESS-CM2 r5i1p1f1...
# Processing EAWR-pos2 historical for ACCESS-CM2 r5i1p1f1...
# Processing SCA-neg1 historical for ACCESS-CM2 r5i1p1f1...
# Processing SCA-neg2 historical for ACCESS-CM2 r5i1p1f1...
# Processing SCA-pos1 historical for ACCESS-CM2 r5i1p1f1...
# Processing NAO-neg1 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing NAO-pos1 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing EA-neg1 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing EA-neg2 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing EA-pos1 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing EAWR-neg1 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing EAWR-pos1 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing EAWR-pos2 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing SCA-neg1 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing SCA-neg2 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing SCA-pos1 ssp585 for ACCESS-CM2 r4i1p1f1...
# Processing NAO-neg1 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing NAO-pos1 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing EA-neg1 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing EA-neg2 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing EA-pos1 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing EAWR-neg1 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing EAWR-pos1 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing EAWR-pos2 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing SCA-neg1 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing SCA-neg2 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing SCA-pos1 ssp585 for ACCESS-CM2 r5i1p1f1...
# Processing NAO-neg1 historical for CanESM5 r10i1p1f1...
# Processing NAO-pos1 historical for CanESM5 r10i1p1f1...
# Processing EA-neg1 historical for CanESM5 r10i1p1f1...
# Processing EA-neg2 historical for CanESM5 r10i1p1f1...
# Processing EA-pos1 historical for CanESM5 r10i1p1f1...
# Processing EAWR-neg1 historical for CanESM5 r10i1p1f1...
# Processing EAWR-pos1 historical for CanESM5 r10i1p1f1...
# Processing EAWR-pos2 historical for CanESM5 r10i1p1f1...
# Processing SCA-neg1 historical for CanESM5 r10i1p1f1...
# Processing SCA-neg2 historical for CanESM5 r10i1p1f1...
# Processing SCA-pos1 historical for CanESM5 r10i1p1f1...
# Processing NAO-neg1 historical for CanESM5 r10i1p2f1...
# Processing NAO-pos1 historical for CanESM5 r10i1p2f1...
# Processing EA-neg1 historical for CanESM5 r10i1p2f1...
# Processing EA-neg2 historical for CanESM5 r10i1p2f1...
# Processing EA-pos1 historical for CanESM5 r10i1p2f1...
# Processing EAWR-neg1 historical for CanESM5 r10i1p2f1...
# Processing EAWR-pos1 historical for CanESM5 r10i1p2f1...
# Processing EAWR-pos2 historical for CanESM5 r10i1p2f1...
# Processing SCA-neg1 historical for CanESM5 r10i1p2f1...
# Processing SCA-neg2 historical for CanESM5 r10i1p2f1...
# Processing SCA-pos1 historical for CanESM5 r10i1p2f1...
# Processing NAO-neg1 historical for CanESM5 r11i1p1f1...
# Processing NAO-pos1 historical for CanESM5 r11i1p1f1...
# Processing EA-neg1 historical for CanESM5 r11i1p1f1...
# Processing EA-neg2 historical for CanESM5 r11i1p1f1...
# Processing EA-pos1 historical for CanESM5 r11i1p1f1...
# Processing EAWR-neg1 historical for CanESM5 r11i1p1f1...
# Processing EAWR-pos1 historical for CanESM5 r11i1p1f1...
# Processing EAWR-pos2 historical for CanESM5 r11i1p1f1...
# Processing SCA-neg1 historical for CanESM5 r11i1p1f1...
# Processing SCA-neg2 historical for CanESM5 r11i1p1f1...
# Processing SCA-pos1 historical for CanESM5 r11i1p1f1...
# Processing NAO-neg1 ssp585 for CanESM5 r10i1p1f1...
# Processing NAO-pos1 ssp585 for CanESM5 r10i1p1f1...
# Processing EA-neg1 ssp585 for CanESM5 r10i1p1f1...
# Processing EA-neg2 ssp585 for CanESM5 r10i1p1f1...
# Processing EA-pos1 ssp585 for CanESM5 r10i1p1f1...
# Processing EAWR-neg1 ssp585 for CanESM5 r10i1p1f1...
# Processing EAWR-pos1 ssp585 for CanESM5 r10i1p1f1...
# Processing EAWR-pos2 ssp585 for CanESM5 r10i1p1f1...
# Processing SCA-neg1 ssp585 for CanESM5 r10i1p1f1...
# Processing SCA-neg2 ssp585 for CanESM5 r10i1p1f1...
# Processing SCA-pos1 ssp585 for CanESM5 r10i1p1f1...
# Processing NAO-neg1 ssp585 for CanESM5 r10i1p2f1...
# Processing NAO-pos1 ssp585 for CanESM5 r10i1p2f1...
# Processing EA-neg1 ssp585 for CanESM5 r10i1p2f1...
# Processing EA-neg2 ssp585 for CanESM5 r10i1p2f1...
# Processing EA-pos1 ssp585 for CanESM5 r10i1p2f1...
# Processing EAWR-neg1 ssp585 for CanESM5 r10i1p2f1...
# Processing EAWR-pos1 ssp585 for CanESM5 r10i1p2f1...
# Processing EAWR-pos2 ssp585 for CanESM5 r10i1p2f1...
# Processing SCA-neg1 ssp585 for CanESM5 r10i1p2f1...
# Processing SCA-neg2 ssp585 for CanESM5 r10i1p2f1...
# Processing SCA-pos1 ssp585 for CanESM5 r10i1p2f1...
# Processing NAO-neg1 ssp585 for CanESM5 r1i1p1f1...
# Processing NAO-pos1 ssp585 for CanESM5 r1i1p1f1...
# Processing EA-neg1 ssp585 for CanESM5 r1i1p1f1...
# Processing EA-neg2 ssp585 for CanESM5 r1i1p1f1...
# Processing EA-pos1 ssp585 for CanESM5 r1i1p1f1...
# Processing EAWR-neg1 ssp585 for CanESM5 r1i1p1f1...
# Processing EAWR-pos1 ssp585 for CanESM5 r1i1p1f1...
# Processing EAWR-pos2 ssp585 for CanESM5 r1i1p1f1...
# Processing SCA-neg1 ssp585 for CanESM5 r1i1p1f1...
# Processing SCA-neg2 ssp585 for CanESM5 r1i1p1f1...
# Processing SCA-pos1 ssp585 for CanESM5 r1i1p1f1...
# Processing NAO-neg1 historical for CNRM-CM6-1 r10i1p1f2...
# Processing NAO-pos1 historical for CNRM-CM6-1 r10i1p1f2...
# Processing EA-neg1 historical for CNRM-CM6-1 r10i1p1f2...
# Processing EA-neg2 historical for CNRM-CM6-1 r10i1p1f2...
# Processing EA-pos1 historical for CNRM-CM6-1 r10i1p1f2...
# Processing EAWR-neg1 historical for CNRM-CM6-1 r10i1p1f2...
# Processing EAWR-pos1 historical for CNRM-CM6-1 r10i1p1f2...
# Processing EAWR-pos2 historical for CNRM-CM6-1 r10i1p1f2...
# Processing SCA-neg1 historical for CNRM-CM6-1 r10i1p1f2...
# Processing SCA-neg2 historical for CNRM-CM6-1 r10i1p1f2...
# Processing SCA-pos1 historical for CNRM-CM6-1 r10i1p1f2...
# Processing NAO-neg1 historical for CNRM-CM6-1 r1i1p1f2...
# Processing NAO-pos1 historical for CNRM-CM6-1 r1i1p1f2...
# Processing EA-neg1 historical for CNRM-CM6-1 r1i1p1f2...
# Processing EA-neg2 historical for CNRM-CM6-1 r1i1p1f2...
# Processing EA-pos1 historical for CNRM-CM6-1 r1i1p1f2...
# Processing EAWR-neg1 historical for CNRM-CM6-1 r1i1p1f2...
# Processing EAWR-pos1 historical for CNRM-CM6-1 r1i1p1f2...
# Processing EAWR-pos2 historical for CNRM-CM6-1 r1i1p1f2...
# Processing SCA-neg1 historical for CNRM-CM6-1 r1i1p1f2...
# Processing SCA-neg2 historical for CNRM-CM6-1 r1i1p1f2...
# Processing SCA-pos1 historical for CNRM-CM6-1 r1i1p1f2...
# Processing NAO-neg1 historical for CNRM-CM6-1 r2i1p1f2...
# Processing NAO-pos1 historical for CNRM-CM6-1 r2i1p1f2...
# Processing EA-neg1 historical for CNRM-CM6-1 r2i1p1f2...
# Processing EA-neg2 historical for CNRM-CM6-1 r2i1p1f2...
# Processing EA-pos1 historical for CNRM-CM6-1 r2i1p1f2...
# Processing EAWR-neg1 historical for CNRM-CM6-1 r2i1p1f2...
# Processing EAWR-pos1 historical for CNRM-CM6-1 r2i1p1f2...
# Processing EAWR-pos2 historical for CNRM-CM6-1 r2i1p1f2...
# Processing SCA-neg1 historical for CNRM-CM6-1 r2i1p1f2...
# Processing SCA-neg2 historical for CNRM-CM6-1 r2i1p1f2...
# Processing SCA-pos1 historical for CNRM-CM6-1 r2i1p1f2...
# Processing NAO-neg1 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing NAO-pos1 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing EA-neg1 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing EA-neg2 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing EA-pos1 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing EAWR-neg1 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing EAWR-pos1 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing EAWR-pos2 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing SCA-neg1 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing SCA-neg2 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing SCA-pos1 ssp585 for CNRM-CM6-1 r1i1p1f2...
# Processing NAO-neg1 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing NAO-pos1 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing EA-neg1 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing EA-neg2 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing EA-pos1 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing EAWR-neg1 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing EAWR-pos1 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing EAWR-pos2 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing SCA-neg1 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing SCA-neg2 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing SCA-pos1 ssp585 for CNRM-CM6-1 r2i1p1f2...
# Processing NAO-neg1 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing NAO-pos1 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing EA-neg1 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing EA-neg2 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing EA-pos1 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing EAWR-neg1 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing EAWR-pos1 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing EAWR-pos2 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing SCA-neg1 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing SCA-neg2 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing SCA-pos1 ssp585 for CNRM-CM6-1 r3i1p1f2...
# Processing NAO-neg1 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing NAO-pos1 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing EA-neg1 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing EA-neg2 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing EA-pos1 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing EAWR-neg1 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing EAWR-pos1 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing EAWR-pos2 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing SCA-neg1 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing SCA-neg2 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing SCA-pos1 historical for CNRM-ESM2-1 r1i1p1f2...
# Processing NAO-neg1 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing NAO-pos1 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing EA-neg1 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing EA-neg2 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing EA-pos1 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing EAWR-neg1 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing EAWR-pos1 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing EAWR-pos2 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing SCA-neg1 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing SCA-neg2 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing SCA-pos1 historical for CNRM-ESM2-1 r2i1p1f2...
# Processing NAO-neg1 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing NAO-pos1 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing EA-neg1 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing EA-neg2 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing EA-pos1 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing EAWR-neg1 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing EAWR-pos1 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing EAWR-pos2 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing SCA-neg1 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing SCA-neg2 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing SCA-pos1 historical for CNRM-ESM2-1 r3i1p1f2...
# Processing NAO-neg1 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing NAO-pos1 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing EA-neg1 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing EA-neg2 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing EA-pos1 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing EAWR-neg1 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing EAWR-pos1 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing EAWR-pos2 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing SCA-neg1 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing SCA-neg2 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing SCA-pos1 ssp585 for CNRM-ESM2-1 r1i1p1f2...
# Processing NAO-neg1 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing NAO-pos1 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing EA-neg1 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing EA-neg2 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing EA-pos1 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing EAWR-neg1 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing EAWR-pos1 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing EAWR-pos2 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing SCA-neg1 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing SCA-neg2 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing SCA-pos1 ssp585 for CNRM-ESM2-1 r4i1p1f2...
# Processing NAO-neg1 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing NAO-pos1 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing EA-neg1 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing EA-neg2 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing EA-pos1 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing EAWR-neg1 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing EAWR-pos1 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing EAWR-pos2 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing SCA-neg1 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing SCA-neg2 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing SCA-pos1 ssp585 for CNRM-ESM2-1 r5i1p1f2...
# Processing NAO-neg1 historical for EC-Earth3-Veg r1i1p1f1...
# Processing NAO-pos1 historical for EC-Earth3-Veg r1i1p1f1...
# Processing EA-neg1 historical for EC-Earth3-Veg r1i1p1f1...
# Processing EA-neg2 historical for EC-Earth3-Veg r1i1p1f1...
# Processing EA-pos1 historical for EC-Earth3-Veg r1i1p1f1...
# Processing EAWR-neg1 historical for EC-Earth3-Veg r1i1p1f1...
# Processing EAWR-pos1 historical for EC-Earth3-Veg r1i1p1f1...
# Processing EAWR-pos2 historical for EC-Earth3-Veg r1i1p1f1...
# Processing SCA-neg1 historical for EC-Earth3-Veg r1i1p1f1...
# Processing SCA-neg2 historical for EC-Earth3-Veg r1i1p1f1...
# Processing SCA-pos1 historical for EC-Earth3-Veg r1i1p1f1...
# Processing NAO-neg1 historical for EC-Earth3-Veg r4i1p1f1...
# Processing NAO-pos1 historical for EC-Earth3-Veg r4i1p1f1...
# Processing EA-neg1 historical for EC-Earth3-Veg r4i1p1f1...
# Processing EA-neg2 historical for EC-Earth3-Veg r4i1p1f1...
# Processing EA-pos1 historical for EC-Earth3-Veg r4i1p1f1...
# Processing EAWR-neg1 historical for EC-Earth3-Veg r4i1p1f1...
# Processing EAWR-pos1 historical for EC-Earth3-Veg r4i1p1f1...
# Processing EAWR-pos2 historical for EC-Earth3-Veg r4i1p1f1...
# Processing SCA-neg1 historical for EC-Earth3-Veg r4i1p1f1...
# Processing SCA-neg2 historical for EC-Earth3-Veg r4i1p1f1...
# Processing SCA-pos1 historical for EC-Earth3-Veg r4i1p1f1...
# Processing NAO-neg1 historical for EC-Earth3-Veg r2i1p1f1...
# Processing NAO-pos1 historical for EC-Earth3-Veg r2i1p1f1...
# Processing EA-neg1 historical for EC-Earth3-Veg r2i1p1f1...
# Processing EA-neg2 historical for EC-Earth3-Veg r2i1p1f1...
# Processing EA-pos1 historical for EC-Earth3-Veg r2i1p1f1...
# Processing EAWR-neg1 historical for EC-Earth3-Veg r2i1p1f1...
# Processing EAWR-pos1 historical for EC-Earth3-Veg r2i1p1f1...
# Processing EAWR-pos2 historical for EC-Earth3-Veg r2i1p1f1...
# Processing SCA-neg1 historical for EC-Earth3-Veg r2i1p1f1...
# Processing SCA-neg2 historical for EC-Earth3-Veg r2i1p1f1...
# Processing SCA-pos1 historical for EC-Earth3-Veg r2i1p1f1...
# Processing NAO-neg1 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing NAO-pos1 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing EA-neg1 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing EA-neg2 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing EA-pos1 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing EAWR-neg1 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing EAWR-pos1 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing EAWR-pos2 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing SCA-neg1 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing SCA-neg2 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing SCA-pos1 ssp585 for EC-Earth3-Veg r2i1p1f1...
# Processing NAO-neg1 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing NAO-pos1 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing EA-neg1 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing EA-neg2 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing EA-pos1 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing EAWR-neg1 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing EAWR-pos1 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing EAWR-pos2 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing SCA-neg1 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing SCA-neg2 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing SCA-pos1 ssp585 for EC-Earth3-Veg r3i1p1f1...
# Processing NAO-neg1 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing NAO-pos1 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing EA-neg1 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing EA-neg2 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing EA-pos1 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing EAWR-neg1 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing EAWR-pos1 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing EAWR-pos2 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing SCA-neg1 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing SCA-neg2 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing SCA-pos1 ssp585 for EC-Earth3-Veg r1i1p1f1...
# Processing NAO-neg1 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing NAO-pos1 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EA-neg1 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EA-neg2 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EA-pos1 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EAWR-neg1 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EAWR-pos1 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EAWR-pos2 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing SCA-neg1 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing SCA-neg2 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing SCA-pos1 historical for EC-Earth3-Veg-LR r1i1p1f1...
# Processing NAO-neg1 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing NAO-pos1 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EA-neg1 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EA-neg2 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EA-pos1 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EAWR-neg1 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EAWR-pos1 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EAWR-pos2 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing SCA-neg1 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing SCA-neg2 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing SCA-pos1 historical for EC-Earth3-Veg-LR r2i1p1f1...
# Processing NAO-neg1 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing NAO-pos1 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EA-neg1 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EA-neg2 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EA-pos1 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EAWR-neg1 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EAWR-pos1 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EAWR-pos2 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing SCA-neg1 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing SCA-neg2 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing SCA-pos1 historical for EC-Earth3-Veg-LR r3i1p1f1...
# Processing NAO-neg1 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing NAO-pos1 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EA-neg1 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EA-neg2 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EA-pos1 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EAWR-neg1 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EAWR-pos1 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing EAWR-pos2 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing SCA-neg1 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing SCA-neg2 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing SCA-pos1 ssp585 for EC-Earth3-Veg-LR r1i1p1f1...
# Processing NAO-neg1 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing NAO-pos1 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EA-neg1 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EA-neg2 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EA-pos1 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EAWR-neg1 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EAWR-pos1 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing EAWR-pos2 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing SCA-neg1 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing SCA-neg2 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing SCA-pos1 ssp585 for EC-Earth3-Veg-LR r2i1p1f1...
# Processing NAO-neg1 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing NAO-pos1 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EA-neg1 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EA-neg2 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EA-pos1 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EAWR-neg1 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EAWR-pos1 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing EAWR-pos2 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing SCA-neg1 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing SCA-neg2 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing SCA-pos1 ssp585 for EC-Earth3-Veg-LR r3i1p1f1...
# Processing NAO-neg1 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing NAO-pos1 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing EA-neg1 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing EA-neg2 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing EA-pos1 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing EAWR-neg1 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing EAWR-pos1 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing EAWR-pos2 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing SCA-neg1 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing SCA-neg2 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing SCA-pos1 historical for IPSL-CM6A-LR r10i1p1f1...
# Processing NAO-neg1 historical for IPSL-CM6A-LR r11i1p1f1...
# Processing NAO-pos1 historical for IPSL-CM6A-LR r11i1p1f1...
# Processing EA-neg1 historical for IPSL-CM6A-LR r11i1p1f1...
# Processing EA-neg2 historical for IPSL-CM6A-LR r11i1p1f1...
# Processing EA-pos1 historical for IPSL-CM6A-LR r11i1p1f1...
# Processing EAWR-neg1 historical for IPSL-CM6A-LR r11i1p1f1...
# Processing EAWR-pos1 historical for IPSL-CM6A-LR r11i1p1f1...
# ...
# Processing EA-neg1 ssp585 for ACCESS-ESM1-5 r3i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r3i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r3i1p1f1_gn_201501-210012.nc
# Processing EA-neg2 ssp585 for ACCESS-ESM1-5 r3i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r3i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r3i1p1f1_gn_201501-210012.nc
# Processing EA-pos1 ssp585 for ACCESS-ESM1-5 r3i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r3i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r3i1p1f1_gn_201501-210012.nc
# Processing EAWR-neg1 ssp585 for ACCESS-ESM1-5 r3i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r3i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r3i1p1f1_gn_201501-210012.nc
# Processing EAWR-pos1 ssp585 for ACCESS-ESM1-5 r3i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r3i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r3i1p1f1_gn_201501-210012.nc
# Processing EAWR-pos2 ssp585 for ACCESS-ESM1-5 r3i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r3i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r3i1p1f1_gn_201501-210012.nc
# Processing SCA-neg1 ssp585 for ACCESS-ESM1-5 r3i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r3i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r3i1p1f1_gn_201501-210012.nc
# Processing SCA-neg2 ssp585 for ACCESS-ESM1-5 r3i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r3i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r3i1p1f1_gn_201501-210012.nc
# Processing SCA-pos1 ssp585 for ACCESS-ESM1-5 r3i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r3i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r3i1p1f1_gn_201501-210012.nc
# Processing NAO-neg1 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing NAO-pos1 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing EA-neg1 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing EA-neg2 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing EA-pos1 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing EAWR-neg1 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing EAWR-pos1 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing EAWR-pos2 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing SCA-neg1 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing SCA-neg2 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing SCA-pos1 ssp585 for ACCESS-ESM1-5 r2i1p1f1...
# Something's wierd about the time axis, decoding manually
# Look into: /net/atmos/data/cmip6/ssp585//Amon/zg/ACCESS-ESM1-5/r2i1p1f1/gn/zg_Amon_ACCESS-ESM1-5_ssp585_r2i1p1f1_gn_201501-210012.nc
# Processing NAO-neg1 historical for MIROC6 r10i1p1f1...
# Processing NAO-pos1 historical for MIROC6 r10i1p1f1...
# Processing EA-neg1 historical for MIROC6 r10i1p1f1...
# Processing EA-neg2 historical for MIROC6 r10i1p1f1...
# Processing EA-pos1 historical for MIROC6 r10i1p1f1...
# Processing EAWR-neg1 historical for MIROC6 r10i1p1f1...
# Processing EAWR-pos1 historical for MIROC6 r10i1p1f1...
# Processing EAWR-pos2 historical for MIROC6 r10i1p1f1...
# Processing SCA-neg1 historical for MIROC6 r10i1p1f1...
# Processing SCA-neg2 historical for MIROC6 r10i1p1f1...
# Processing SCA-pos1 historical for MIROC6 r10i1p1f1...
# Processing NAO-neg1 historical for MIROC6 r1i1p1f1...
# Processing NAO-pos1 historical for MIROC6 r1i1p1f1...
# Processing EA-neg1 historical for MIROC6 r1i1p1f1...
# Processing EA-neg2 historical for MIROC6 r1i1p1f1...
# Processing EA-pos1 historical for MIROC6 r1i1p1f1...
# Processing EAWR-neg1 historical for MIROC6 r1i1p1f1...
# Processing EAWR-pos1 historical for MIROC6 r1i1p1f1...
# Processing EAWR-pos2 historical for MIROC6 r1i1p1f1...
# Processing SCA-neg1 historical for MIROC6 r1i1p1f1...
# Processing SCA-neg2 historical for MIROC6 r1i1p1f1...
# Processing SCA-pos1 historical for MIROC6 r1i1p1f1...
# Processing NAO-neg1 historical for MIROC6 r2i1p1f1...
# Processing NAO-pos1 historical for MIROC6 r2i1p1f1...
# Processing EA-neg1 historical for MIROC6 r2i1p1f1...
# Processing EA-neg2 historical for MIROC6 r2i1p1f1...
# Processing EA-pos1 historical for MIROC6 r2i1p1f1...
# Processing EAWR-neg1 historical for MIROC6 r2i1p1f1...
# Processing EAWR-pos1 historical for MIROC6 r2i1p1f1...
# Processing EAWR-pos2 historical for MIROC6 r2i1p1f1...
# Processing SCA-neg1 historical for MIROC6 r2i1p1f1...
# Processing SCA-neg2 historical for MIROC6 r2i1p1f1...
# Processing SCA-pos1 historical for MIROC6 r2i1p1f1...
# Processing NAO-neg1 ssp585 for MIROC6 r1i1p1f1...
# Processing NAO-pos1 ssp585 for MIROC6 r1i1p1f1...
# Processing EA-neg1 ssp585 for MIROC6 r1i1p1f1...
# Processing EA-neg2 ssp585 for MIROC6 r1i1p1f1...
# Processing EA-pos1 ssp585 for MIROC6 r1i1p1f1...
# Processing EAWR-neg1 ssp585 for MIROC6 r1i1p1f1...
# Processing EAWR-pos1 ssp585 for MIROC6 r1i1p1f1...
# Processing EAWR-pos2 ssp585 for MIROC6 r1i1p1f1...
# Processing SCA-neg1 ssp585 for MIROC6 r1i1p1f1...
# Processing SCA-neg2 ssp585 for MIROC6 r1i1p1f1...
# Processing SCA-pos1 ssp585 for MIROC6 r1i1p1f1...
# Processing NAO-neg1 ssp585 for MIROC6 r2i1p1f1...
# Processing NAO-pos1 ssp585 for MIROC6 r2i1p1f1...
# Processing EA-neg1 ssp585 for MIROC6 r2i1p1f1...
# Processing EA-neg2 ssp585 for MIROC6 r2i1p1f1...
# Processing EA-pos1 ssp585 for MIROC6 r2i1p1f1...
# Processing EAWR-neg1 ssp585 for MIROC6 r2i1p1f1...
# Processing EAWR-pos1 ssp585 for MIROC6 r2i1p1f1...
# Processing EAWR-pos2 ssp585 for MIROC6 r2i1p1f1...
# Processing SCA-neg1 ssp585 for MIROC6 r2i1p1f1...
# Processing SCA-neg2 ssp585 for MIROC6 r2i1p1f1...
# Processing SCA-pos1 ssp585 for MIROC6 r2i1p1f1...
# Processing NAO-neg1 ssp585 for MIROC6 r3i1p1f1...
# Processing NAO-pos1 ssp585 for MIROC6 r3i1p1f1...
# Processing EA-neg1 ssp585 for MIROC6 r3i1p1f1...
# Processing EA-neg2 ssp585 for MIROC6 r3i1p1f1...
# Processing EA-pos1 ssp585 for MIROC6 r3i1p1f1...
# Processing EAWR-neg1 ssp585 for MIROC6 r3i1p1f1...
# Processing EAWR-pos1 ssp585 for MIROC6 r3i1p1f1...
# Processing EAWR-pos2 ssp585 for MIROC6 r3i1p1f1...
# Processing SCA-neg1 ssp585 for MIROC6 r3i1p1f1...
# Processing SCA-neg2 ssp585 for MIROC6 r3i1p1f1...
# Processing SCA-pos1 ssp585 for MIROC6 r3i1p1f1...
# Processing NAO-neg1 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing NAO-pos1 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing EA-neg1 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing EA-neg2 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing EA-pos1 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing EAWR-neg1 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing EAWR-pos1 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing EAWR-pos2 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing SCA-neg1 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing SCA-neg2 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing SCA-pos1 historical for MPI-ESM1-2-LR r10i1p1f1...
# Processing NAO-neg1 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing NAO-pos1 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing EA-neg1 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing EA-neg2 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing EA-pos1 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing EAWR-neg1 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing EAWR-pos1 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing EAWR-pos2 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing SCA-neg1 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing SCA-neg2 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing SCA-pos1 historical for MPI-ESM1-2-LR r9i1p1f1...
# Processing NAO-neg1 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing NAO-pos1 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing EA-neg1 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing EA-neg2 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing EA-pos1 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing EAWR-neg1 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing EAWR-pos1 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing EAWR-pos2 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing SCA-neg1 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing SCA-neg2 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing SCA-pos1 historical for MPI-ESM1-2-LR r5i1p1f1...
# Processing NAO-neg1 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing NAO-pos1 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing EA-neg1 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing EA-neg2 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing EA-pos1 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing EAWR-neg1 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing EAWR-pos1 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing EAWR-pos2 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing SCA-neg1 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing SCA-neg2 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing SCA-pos1 ssp585 for MPI-ESM1-2-LR r1i1p1f1...
# Processing NAO-neg1 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing NAO-pos1 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing EA-neg1 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing EA-neg2 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing EA-pos1 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing EAWR-neg1 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing EAWR-pos1 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing EAWR-pos2 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing SCA-neg1 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing SCA-neg2 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing SCA-pos1 ssp585 for MPI-ESM1-2-LR r10i1p1f1...
# Processing NAO-neg1 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing NAO-pos1 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing EA-neg1 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing EA-neg2 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing EA-pos1 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing EAWR-neg1 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing EAWR-pos1 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing EAWR-pos2 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing SCA-neg1 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing SCA-neg2 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing SCA-pos1 ssp585 for MPI-ESM1-2-LR r3i1p1f1...
# Processing NAO-neg1 historical for KACE-1-0-G r2i1p1f1...
# Processing NAO-pos1 historical for KACE-1-0-G r2i1p1f1...
# Processing EA-neg1 historical for KACE-1-0-G r2i1p1f1...
# Processing EA-neg2 historical for KACE-1-0-G r2i1p1f1...
# Processing EA-pos1 historical for KACE-1-0-G r2i1p1f1...
# Processing EAWR-neg1 historical for KACE-1-0-G r2i1p1f1...
# Processing EAWR-pos1 historical for KACE-1-0-G r2i1p1f1...
# Processing EAWR-pos2 historical for KACE-1-0-G r2i1p1f1...
# Processing SCA-neg1 historical for KACE-1-0-G r2i1p1f1...
# Processing SCA-neg2 historical for KACE-1-0-G r2i1p1f1...
# Processing SCA-pos1 historical for KACE-1-0-G r2i1p1f1...
# Processing NAO-neg1 historical for KACE-1-0-G r1i1p1f1...
# Processing NAO-pos1 historical for KACE-1-0-G r1i1p1f1...
# Processing EA-neg1 historical for KACE-1-0-G r1i1p1f1...
# Processing EA-neg2 historical for KACE-1-0-G r1i1p1f1...
# Processing EA-pos1 historical for KACE-1-0-G r1i1p1f1...
# Processing EAWR-neg1 historical for KACE-1-0-G r1i1p1f1...
# Processing EAWR-pos1 historical for KACE-1-0-G r1i1p1f1...
# Processing EAWR-pos2 historical for KACE-1-0-G r1i1p1f1...
# Processing SCA-neg1 historical for KACE-1-0-G r1i1p1f1...
# Processing SCA-neg2 historical for KACE-1-0-G r1i1p1f1...
# Processing SCA-pos1 historical for KACE-1-0-G r1i1p1f1...
# Processing NAO-neg1 historical for KACE-1-0-G r3i1p1f1...
# Processing NAO-pos1 historical for KACE-1-0-G r3i1p1f1...
# Processing EA-neg1 historical for KACE-1-0-G r3i1p1f1...
# Processing EA-neg2 historical for KACE-1-0-G r3i1p1f1...
# Processing EA-pos1 historical for KACE-1-0-G r3i1p1f1...
# Processing EAWR-neg1 historical for KACE-1-0-G r3i1p1f1...
# Processing EAWR-pos1 historical for KACE-1-0-G r3i1p1f1...
# Processing EAWR-pos2 historical for KACE-1-0-G r3i1p1f1...
# Processing SCA-neg1 historical for KACE-1-0-G r3i1p1f1...
# Processing SCA-neg2 historical for KACE-1-0-G r3i1p1f1...
# Processing SCA-pos1 historical for KACE-1-0-G r3i1p1f1...
# Processing NAO-neg1 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing NAO-pos1 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing EA-neg1 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing EA-neg2 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing EA-pos1 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing EAWR-neg1 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing EAWR-pos1 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing EAWR-pos2 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing SCA-neg1 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing SCA-neg2 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing SCA-pos1 ssp585 for KACE-1-0-G r1i1p1f1...
# Processing NAO-neg1 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing NAO-pos1 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing EA-neg1 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing EA-neg2 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing EA-pos1 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing EAWR-neg1 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing EAWR-pos1 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing EAWR-pos2 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing SCA-neg1 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing SCA-neg2 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing SCA-pos1 ssp585 for KACE-1-0-G r2i1p1f1...
# Processing NAO-neg1 ssp585 for KACE-1-0-G r3i1p1f1...
# Processing NAO-pos1 ssp585 for KACE-1-0-G r3i1p1f1...
# Processing EA-neg1 ssp585 for KACE-1-0-G r3i1p1f1...
# Processing EA-neg2 ssp585 for KACE-1-0-G r3i1p1f1...
# Processing EA-pos1 ssp585 for KACE-1-0-G r3i1p1f1...
# Processing EAWR-neg1 ssp585 for KACE-1-0-G r3i1p1f1...
# Processing EAWR-pos1 ssp585 for KACE-1-0-G r3i1p1f1...
# Processing EAWR-pos2 ssp585 for KACE-1-0-G r3i1p1f1...
# Processing SCA-neg1 ssp585 for KACE-1-0-G r3i1p1f1...
# Processing SCA-neg2 ssp585 for KACE-1-0-G r3i1p1f1...
# Processing SCA-pos1 ssp585 for KACE-1-0-G r3i1p1f1...

# %%
savename="_".join(["mon_ts","WAN","weather","indices","CU21","sp_avg",modset]+selscen)+".nc"
ind_ds.to_netcdf("/home/lseverino/MT/circulation/"+savename)

# %%
ind_ds2 = xr.open_dataset("/home/lseverino/MT/circulation/"+savename)

# %%
idx = pd.IndexSlice
diff = ind_df.loc[:,idx[:,"ssp585"]] - ind_df.loc[:,idx[:,"historical"]].values
diff_mean = diff.groupby("model").mean()

# %%
diff_mean
# Out:
# indice                NAO-neg1  NAO-pos1   EA-neg1       EA-neg2  \
# scen                    ssp585    ssp585    ssp585        ssp585
# model
# ACCESS-CM2        1.536563e-05 -0.000061  0.000061  2.262584e-06
# ACCESS-ESM1-5     1.934709e-05  0.000081  0.000004  5.404699e-05
# AWI-CM-1-1-MR    -4.749135e-05  0.000014  0.000008 -3.838366e-05
# BCC-CSM2-MR       1.016339e-05  0.000049 -0.000025 -1.556587e-05
# CMCC-CM2-SR5      4.306667e-05  0.000002  0.000010 -6.134683e-05
# CMCC-ESM2         4.201379e-05 -0.000020 -0.000028  1.076220e-07
# CNRM-CM6-1       -2.814682e-05 -0.000009 -0.000072  4.944561e-05
# CNRM-CM6-1-HR     5.588299e-05 -0.000070 -0.000016  1.100393e-04
# CNRM-ESM2-1       1.640421e-05  0.000091 -0.000106 -5.077780e-05
# CanESM5           4.628776e-05  0.000126 -0.000030 -3.122580e-05
# EC-Earth3-CC     -7.488664e-06 -0.000029 -0.000004 -2.175321e-06
# EC-Earth3-Veg     1.830660e-05 -0.000016  0.000019  1.410871e-05
# EC-Earth3-Veg-LR -2.613712e-05 -0.000016 -0.000019 -1.774969e-05
# FGOALS-g3        -2.735937e-05  0.000031 -0.000059  1.070702e-04
# GFDL-CM4         -8.560802e-05 -0.000096  0.000017 -1.370806e-05
# GISS-E2-1-G       3.855851e-06  0.000036  0.000182 -1.085059e-05
# HadGEM3-GC31-LL  -3.296436e-05  0.000027 -0.000045  7.938872e-06
# HadGEM3-GC31-MM   1.095744e-05  0.000033 -0.000010 -7.466100e-06
# INM-CM4-8        -3.653496e-05 -0.000009  0.000024 -9.482871e-06
# INM-CM5-0         4.245425e-08 -0.000067 -0.000087 -3.583454e-06
# IPSL-CM6A-LR      2.588343e-05 -0.000017  0.000024  4.814995e-05
# KACE-1-0-G        1.393726e-05  0.000087  0.000047 -5.336681e-05
# MIROC-ES2L        6.825293e-05 -0.000010  0.000086  6.761678e-05
# MIROC6           -5.355022e-05  0.000004  0.000027  1.019719e-06
# MPI-ESM1-2-HR    -4.152661e-05 -0.000045 -0.000008  2.724049e-05
# MPI-ESM1-2-LR     1.810007e-05 -0.000035 -0.000007  2.024419e-05
# MRI-ESM2-0        2.951703e-06  0.000002  0.000041 -7.273793e-06
# NESM3            -6.721550e-06  0.000022 -0.000116 -1.281982e-04
# UKESM1-0-LL       4.286337e-05  0.000043 -0.000110 -4.536357e-05
#
# indice                 EA-pos1     EAWR-neg1 EAWR-pos1 EAWR-pos2  \
# scen                    ssp585        ssp585    ssp585    ssp585
# model
# ACCESS-CM2       -2.796411e-05 -3.157212e-05  0.000029  0.000006
# ACCESS-ESM1-5    -1.016839e-05 -4.819767e-05  0.000019 -0.000019
# AWI-CM-1-1-MR     2.976814e-05 -1.678305e-05  0.000008 -0.000041
# BCC-CSM2-MR      -6.710615e-05  3.424309e-06  0.000036  0.000116
# CMCC-CM2-SR5     -7.052908e-08  2.867971e-08 -0.000080  0.000013
# CMCC-ESM2         4.040627e-05 -2.668466e-05  0.000009  0.000049
# CNRM-CM6-1        1.354160e-05 -3.891374e-05 -0.000035  0.000020
# CNRM-CM6-1-HR    -5.857243e-05  4.172158e-05 -0.000093  0.000004
# CNRM-ESM2-1      -8.866520e-06 -5.862509e-06 -0.000030  0.000005
# CanESM5           4.379378e-05  4.932329e-05  0.000054 -0.000005
# EC-Earth3-CC     -2.850974e-05 -2.817873e-05 -0.000011  0.000078
# EC-Earth3-Veg     2.352518e-05  2.778613e-05  0.000019  0.000031
# EC-Earth3-Veg-LR -1.721898e-06 -2.648998e-05  0.000013 -0.000016
# FGOALS-g3        -2.439619e-05  1.952736e-05  0.000016  0.000010
# GFDL-CM4          4.816706e-06  3.805522e-05 -0.000050  0.000066
# GISS-E2-1-G      -3.558068e-05 -9.536034e-05 -0.000039  0.000031
# HadGEM3-GC31-LL  -5.727748e-05 -2.221508e-05 -0.000071 -0.000032
# HadGEM3-GC31-MM   8.083601e-08 -7.280821e-06 -0.000005 -0.000007
# INM-CM4-8         1.844929e-05  2.587698e-05 -0.000012 -0.000034
# INM-CM5-0         2.283725e-05 -3.339577e-05 -0.000149 -0.000042
# IPSL-CM6A-LR      2.616600e-05 -3.605595e-05 -0.000018 -0.000012
# KACE-1-0-G        2.048145e-05 -3.631878e-05 -0.000036 -0.000096
# MIROC-ES2L       -1.209479e-05 -9.886388e-06  0.000112 -0.000009
# MIROC6            1.611505e-05  3.406850e-06 -0.000045  0.000012
# MPI-ESM1-2-HR     1.534264e-05 -1.065170e-05 -0.000013  0.000032
# MPI-ESM1-2-LR    -1.651036e-05 -1.247149e-05  0.000041 -0.000012
# MRI-ESM2-0        2.304994e-05 -2.079907e-06  0.000030 -0.000023
# NESM3             3.616392e-05  2.162765e-05  0.000049 -0.000008
# UKESM1-0-LL      -1.974767e-05 -2.859278e-05 -0.000011  0.000029
#
# indice                SCA-neg1  SCA-neg2  SCA-pos1
# scen                    ssp585    ssp585    ssp585
# model
# ACCESS-CM2       -3.167973e-05 -0.000092  0.000030
# ACCESS-ESM1-5    -3.629440e-05 -0.000032 -0.000037
# AWI-CM-1-1-MR     6.835006e-05  0.000014 -0.000022
# BCC-CSM2-MR      -2.445987e-08 -0.000132  0.000152
# CMCC-CM2-SR5     -3.271589e-05  0.000059  0.000013
# CMCC-ESM2        -2.231943e-05  0.000021 -0.000051
# CNRM-CM6-1        2.005468e-05 -0.000046  0.000011
# CNRM-CM6-1-HR    -6.645177e-05  0.000021 -0.000022
# CNRM-ESM2-1      -5.967988e-05 -0.000063  0.000027
# CanESM5           4.332668e-05  0.000059 -0.000109
# EC-Earth3-CC     -3.158003e-05 -0.000055  0.000045
# EC-Earth3-Veg     1.382724e-05  0.000060 -0.000006
# EC-Earth3-Veg-LR -1.540634e-05 -0.000005 -0.000039
# FGOALS-g3        -1.147347e-05 -0.000045 -0.000029
# GFDL-CM4          3.668166e-05 -0.000244  0.000063
# GISS-E2-1-G      -2.054932e-05  0.000144 -0.000130
# HadGEM3-GC31-LL  -1.431778e-05 -0.000033 -0.000052
# HadGEM3-GC31-MM   1.861182e-05  0.000018 -0.000008
# INM-CM4-8        -1.139298e-04 -0.000033  0.000010
# INM-CM5-0        -9.913477e-06  0.000026  0.000020
# IPSL-CM6A-LR      4.604481e-05 -0.000121 -0.000035
# KACE-1-0-G        2.657220e-05  0.000123 -0.000015
# MIROC-ES2L        6.915711e-05 -0.000050  0.000086
# MIROC6           -3.526765e-05 -0.000072 -0.000003
# MPI-ESM1-2-HR    -2.562309e-05  0.000020  0.000020
# MPI-ESM1-2-LR    -3.943418e-05  0.000074 -0.000042
# MRI-ESM2-0       -3.207266e-05  0.000040 -0.000094
# NESM3            -2.781794e-05  0.000131  0.000095
# UKESM1-0-LL       4.884009e-05  0.000071 -0.000043

# %%
diff_mean.mean()
# Out:
# indice     scen
# NAO-neg1   ssp585    2.074261e-06
# NAO-pos1   ssp585    5.048131e-06
# EA-neg1    ssp585   -6.660787e-06
# EA-neg2    ssp585    4.404369e-07
# EA-pos1    ssp585   -1.174099e-06
# EAWR-neg1  ssp585   -9.869429e-06
# EAWR-pos1  ssp585   -9.050506e-06
# EAWR-pos2  ssp585    5.143737e-06
# SCA-neg1   ssp585   -8.106378e-06
# SCA-neg2   ssp585   -4.938508e-06
# SCA-pos1   ssp585   -5.633489e-06
# dtype: float64

# %%
field_avg.mean()
# Out:
# 20.36402635997781
